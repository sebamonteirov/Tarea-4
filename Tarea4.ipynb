# %% [markdown]
# # **CD2201-16: Ciencia de Datos en Astronomía**
#
# **Profesores:** Boris Cuevas, Paula Díaz, Danilo Sepúlveda, Francisco Urbina
#
# # **Tarea 4: Analizando un cubo de datos**
#
# En clases ya vimos varios tipos de datos que utilizamos para analizar objetos astronómicos, como lo hacen las técnicas de fotometria y espectroscopia. En principio, se puede entender la fotometría como un "subconjunto" de la espectroscopia, pero esta última es mucho más costosa.
#
# Con un único espectro solo podemos analizar cómo se descompone la luz de un único objeto, lo cual puede ser muy útil si estudiamos objetos puntuales. En algunos casos queremos estudiar objetos "extendidos" en el cielo, como las galaxias o explorar los espectros de muchas estrellas de forma simultánea (como en un cúmulo de estrellas). Para este tipo de casos, es ideal obtener un espectro para cada posición del cielo alrededor de algún objeto central. Esto se suele conocer como "Espectroscopia de campo integral" (IFS por sus siglas en inglés).
#
# En esta minitarea exploraremos un cubo de datos, aprenderemos a como entender su formato, extraer información fundamental e identificar algunos objetos extrayendo su espectro.

# %% [markdown]
# ## A jugar con los datos!
#
# Descargue los datos que vamos a utilizar en el siguiente [link.](https://drive.google.com/file/d/1V7j-WJpTY9fZwajyhpp_Vj9ZZ1rjKN_j/view?usp=sharing)
#
# **CUIDADO:** los datos pesan ~3 Gb, usted debe descargarlos y subirlos a alguna carpeta de Drive (misma carpeta donde tendrá esta tarea!).

# %%
# Partiremos por "montar" el drive, esto permite que podamos leer los archivos de nuestro drive
from google.colab import drive
drive.mount('/content/drive')    # se les debe abrir una pestaña extra pidiendo permisos
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Encuentren la ruta de su archivo, para ello puede utilizar la barra de herramientas izquierda
# lleguen a su archivo desde su "drive" y con el click derecho "copiar ruta" y luego la pegan
# como un string en la siguiente variable.
path_archivo = '/content/drive/MyDrive/Modulo_astronomia_y_ciencia_de_datos/CSWA31_MUSE_vacuum_zap.fits'

# %% [markdown]
# Cargue el cubo de datos con astropy en la siguiente celda.

# %%
import astropy.io.fits as F
cubo = F.open(path_archivo)

# %% [markdown]
# Muestre el *header* de la primera extensión de la variable cubo.

# %%
# Muestre el header (es recomendable que no use "print" en esta ocasión)
cubo[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# ORIGIN  = 'ESO-PARANAL'        / European Southern Observatory
# TELESCOP= 'ESO-VLT-U4'         / ESO <TEL>
# INSTRUME= 'MUSE    '           / Instrument used.
# RA      =           140.357084 / [deg] 09:21:25.7 RA (J2000) pointing
# DEC     =              18.1713 / [deg] 18:10:16.6 DEC (J2000) pointing
# EQUINOX =               2000.0 / Standard FK5
# EXPTIME =              13575.0 / Integration time
# MJD-OBS =       58841.29679796 / Obs start
# DATE-OBS= '2019-12-24T07:07:23.343' / Observing date
# PI-COI  = 'UNKNOWN '           / PI-COI name.
# OBSERVER= 'UNKNOWN '           / Name of observer.
# OBJECT  = 'CSWA 31 '           / Original target.
# HIERARCH ESO INS DROT POSANG = 0.0 / [deg] Derotator position angle
# HIERARCH ESO INS MODE = 'WFM-NOAO-N' / Instrument mode used
# HIERARCH ESO DET READ CURID = 1 / Used readout mode id
# HIERARCH ESO INS TEMP11 VAL = 15.82 / [C] Left IFU temperature
# HIERARCH ESO OBS ID = 2509894 / Observation block ID
# HIERARCH ESO OBS NAME = 'WFM_CSWA31_1' / OB name
# HIERARCH ESO OBS START = '2019-12-24T07:00:41' / OB start time
# HIERARCH ESO TEL AIRM END = 1.374 / Airmass at end
# HIERARCH ESO TEL AIRM START = 1.394 / Airmass at start
# HIERARCH ESO TEL AMBI FWHM END = 0.49 / [arcsec] Observatory Seeing queried from
# HIERARCH ESO TEL AMBI FWHM START = 0.51 / [arcsec] Observatory Seeing queried fr
# HIERARCH MPDAF METH1 VERSION = '3.5     ' / MPDAF version
# HIERARCH MPDAF METH1 ID = 'obj.cubelist.merging' / MPDAF method identifier
# HIERARCH MPDAF METH1 PARAM1 NAME = 'nmax    ' / max number of clipping iteration
# HIERARCH MPDAF METH1 PARAM1 VALUE = 2
# HIERARCH MPDAF METH1 PARAM2 NAME = 'nclip_low' / lower clipping parameter
# HIERARCH MPDAF METH1 PARAM2 VALUE = 5.0
# HIERARCH MPDAF METH1 PARAM3 NAME = 'nclip_up' / upper clipping parameter
# HIERARCH MPDAF METH1 PARAM3 VALUE = 5.0
# HIERARCH MPDAF METH1 PARAM4 NAME = 'nstop   ' / clipping minimum number
# HIERARCH MPDAF METH1 PARAM4 VALUE = 2
# HIERARCH MPDAF METH1 PARAM5 NAME = 'var     ' / type of variance
# HIERARCH MPDAF METH1 PARAM5 VALUE = 'propagate'
# NFILES  =                   15 / number of files merged in the cube
# DATE    = '2024-05-08 15:16:35.387745' / creation date
# AUTHOR  = 'MPDAF   '           / origin of the file
# COMMENT List of cubes merged in this cube:
# COMMENT - DATACUBE_FINAL.fits
# COMMENT - DATACUBE_FINAL.fits
# COMMENT - DATACUBE_FINAL.fits
# COMMENT - DATACUBE_FINAL.fits
# COMMENT - DATACUBE_FINAL.fits
# COMMENT - DATACUBE_FINAL.fits
# COMMENT - DATACUBE_FINAL.fits
# COMMENT - DATACUBE_FINAL.fits
# COMMENT - DATACUBE_FINAL.fits
# COMMENT - DATACUBE_FINAL.fits
# COMMENT - DATACUBE_FINAL.fits
# COMMENT - DATACUBE_FINAL.fits
# COMMENT - DATACUBE_FINAL.fits
# COMMENT - DATACUBE_FINAL.fits
# COMMENT - DATACUBE_FINAL.fits

# %% [markdown]
# Examinando la información desplegada responda:
#
# 1.   ¿Qué telescopio tomó los datos? ESO-VLT-U4
# 2.   ¿Qué instrumento lo hizo? MUSE
# 3.   ¿Cuál es el nombre del objeto observado? CSWA 31
# 4.   Reporte el valor de la variable 'EXPTIME' del header. Esto corresponde al *tiempo de integración* que se necesito para obtener los datos. ¿A qué corresponde ese tiempo? 13575.0
#
# **Respuesta:**
#
# 1.   ESO-VLT-U4
# 2.   MUSE
# 3.   CSWA 31
# 4.   13575.0 - Integration Time

# %% [markdown]
# Ahora que ya conoce el telescopio y el instrumento que tomó los datos, investigue y responda las siguientes preguntas:
#
# 1. ¿De que tamaño es el diámetro del espejo del telescopio?
# 2. ¿Cuán grande es el campo de visión que examina el instrumento (Field of view o FOV en inglés)? Compare dicho campo de visión con el tamaño angular de la luna visto desde la tierra (algo así como medio grado) ¿Cuántos campos de visión del intrumento "caben" en la luna?.
# 3. ¿Qué rango de longitud de onda explora este instrumento?
#
# **Respuesta:**
#
# 1. 8,2 metros
# 2. 59.9"x 60.0". La luna mide medio grado = 0.5 grados * 3600 segundos/grado = 1800 segundos de arco.
#
# En el eje más corto del FOV: 1800 segundos de arco / 59.9 segundos de arco = 30.05
# En el eje más largo del FOV: 1800 segundos de arco / 60.0 segundos de arco = 30
#
# Por lo tanto, aproximadamente, caben 30 campos de visión de MUSE en el diámetro de la Luna.
#
# 3.
#
# 480-930 nm (nominal)
#
# 465-930 nm (extended)

# %% [markdown]
# Explore la extensión asociada a los datos (índice = 1).
# Extraiga los datos y describa cada eje del cubo. ¿En que unidades se encuentran los datos?
# **Respuesta:**
#
# **Hint:** explore las variables 'CTYPE', estas le indicarán a que corresponde cada eje del cubo. Las unidades se encontrarán en la variable 'BUNIT'.

# %%
# Muestre el header de la primera extensión (índice = 1) aquí.
header1 = cubo[1].header
header1
# Out:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    3 / number of array dimensions
# NAXIS1  =                  322
# NAXIS2  =                  325
# NAXIS3  =                 3682
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# WCSAXES =                    3 / Number of coordinate axes
# CRPIX1  =      160.93047228529 / Pixel coordinate of reference point
# CRPIX2  =       162.3187381719 / Pixel coordinate of reference point
# CUNIT1  = 'deg'                / Units of coordinate increment and value
# CUNIT2  = 'deg'                / Units of coordinate increment and value
# CTYPE1  = 'RA---TAN'           / Right ascension, gnomonic projection
# CTYPE2  = 'DEC--TAN'           / Declination, gnomonic projection
# CRVAL1  =      140.35724395618 / [deg] Coordinate value at reference point
# CRVAL2  =      18.171489819048 / [deg] Coordinate value at reference point
# LONPOLE =                180.0 / [deg] Native longitude of celestial pole
# LATPOLE =      18.171489819048 / [deg] Native latitude of celestial pole
# CSYER1  =     1.2298399761E-05 / [deg] Systematic error in coordinate
# CSYER2  =    9.26900810156E-06 / [deg] Systematic error in coordinate
# MJDREF  =                  0.0 / [d] MJD of fiducial time
# RADESYS = 'FK5'                / Equatorial coordinate system
# EQUINOX =               2000.0 / [yr] Equinox of equatorial coordinates
# CD1_1   = -5.5555555555556E-05
# CD1_2   =                  0.0
# CD2_1   =                  0.0
# CD2_2   =  5.5555555555556E-05
# CRVAL3  =     4751.66303877044 / Coordinate value at reference point
# CRPIX3  =                  1.0 / Pixel coordinate of reference point
# CUNIT3  = 'Angstrom'           / Units of coordinate increment and value
# CTYPE3  = 'WAVE    '           / Coordinate type code
# CD3_3   =                 1.25
# CD1_3   =                  0.0
# CD2_3   =                  0.0
# CD3_1   =                  0.0
# CD3_2   =                  0.0
# OBJECT  = 'CSWA 31 '
# BUNIT   = '10**-20 Angstrom-1 cm-2 erg s-1' / data unit type
# EXTNAME = 'DATA    '           / extension name
# COMMENT These data have been ZAPped!
# ZAPVERS = '2.1     '           / ZAP version
# ZAPZLVL = 'median  '           / ZAP zero level correction
# ZAPCLEAN=                    T / ZAP NaN cleaning performed for calculation
# ZAPCFTYP= 'median  '           / ZAP continuum filter type
# ZAPCFWID=                  300 / ZAP continuum filter size
# ZAPNSEG =                    1 / Number of segments used for ZAP SVD
# ZAPSEG0 = '0:3681  '           / spectrum segment (pixels)
# ZAPNEV0 =                   71 / number of eigenvals/spectra used

# %%
# Guarde los datos en la siguiente variable.
datos = cubo[1].data

print(f"Eje 1: {header1['CTYPE1']}, Unidades: {header1['BUNIT']}")
print(f"Eje 2: {header1['CTYPE2']}, Unidades: {header1['BUNIT']}")
print(f"Eje 3: {header1['CTYPE3']}, Unidades: {header1['BUNIT']}")
# Out:
# Eje 1: RA---TAN, Unidades: 10**-20 Angstrom-1 cm-2 erg s-1
# Eje 2: DEC--TAN, Unidades: 10**-20 Angstrom-1 cm-2 erg s-1
# Eje 3: WAVE, Unidades: 10**-20 Angstrom-1 cm-2 erg s-1

# %%
print(datos.shape)     # noten que la dimensión de mayor número es la espectral, las otras 2 son espaciales :)
# Out:
# (3682, 325, 322)

# %% [markdown]
# ## White-light image y su visualización
#
# Una white-light image es una imagén en la cual se sumó en la dirección espectral, es decir, sumamos todos los fotones que llegaron en todo el rango explorado, de ahí el origen del nombre.
#
# Cree un código capaz de calcular una white-light image (una línea con numpy), quizá se demore un poco en ejecutar esta parte.

# %%
# Aquí el código.
import numpy as np
white_light_image = np.sum(datos, axis=0)
white_light_image
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=float32)

# %% [markdown]
# Visualice su imagen con plt.imshow().

# %%
import matplotlib.pyplot as plt

plt.imshow(white_light_image, cmap='magma')
plt.colorbar()
plt.title('Imagen de Luz Blanca')
plt.show()

# %% [markdown]
# Notará que en la imagen existen una especie de arcos aproximadamente circulares. Explique brevemente, ¿a qué fenómeno físico corresponde esto?
#
# **Respuesta:** lindos arcos gravitacionales :)

# %% [markdown]
# El resultado crudo de dicha visualización puede mejorar de forma significativa.
# Para ello usted debe:
# 1. Cortar la imagen para enforcarnos en las figuras "semi circulares" que se aprecian.
# 2. Ajustar la scala de la imagen para generar mayor contraste.
# 3. Cambie el mapa de colores a uno que le parezca adecuado ([aquí una lista](https://matplotlib.org/stable/users/explain/colors/colormaps.html)).
# 4. Añadir coordenadas a los ejes y una colorbar.

# %%
import numpy as np                           # utilizaremos su función de cálculo de percentiles

plt.hist(datos[datos < 2].flatten(), bins=100)

# Esta es una forma de generar percentiles "simétricos" no tiene porque ser siempre así.
value = 5
percentiles = np.nanpercentile(datos.flatten(), [value, 100-value ])

plt.vlines([percentiles], [0]*2, [10000]*2, linestyle='--', color='red')
plt.xlabel('electron/s', fontsize=12)
plt.ylabel('Number of pixels', fontsize=12)
plt.show()

# %%
# Solución
from astropy.wcs import WCS
# Utilice el siguiente wcs para añadir las coordenadas a su visualización.
wcs = WCS(cubo[1].header)
wcs = wcs[0,:,:]

plt.subplot(projection=wcs) # Projectamos las coordenadas con el WCS

# Haga su gráfico a continuación:
plt.imshow(white_light_image, cmap='gist_earth')

#escala
value = 0
percentiles = np.nanpercentile(datos.flatten(), [value, 100-value ])
plt.clim(percentiles[0], percentiles[1])   # utilizamos los nuevos límites

plt.xlim(75,250) # Recorte en el eje x
plt.ylim(75,250) # Recorte en el eje y

plt.colorbar(label='electrons/s')

plt.xlabel('J2000 RA')
plt.ylabel('J2000 DEC')

plt.show()

# %% [markdown]
# Para lo que viene utilizaremos una librería creada para lidiar con cubos de datos.
# La instalaremos utilizando **pip**, note que esta instalación es solo en el ambiente de google colab, nada se instalará en su computador.
# La documentación la puede encontrar [aquí.](https://mpdaf.readthedocs.io/en/stable/)

# %%
# !pip install mpdaf
# Out:
# Collecting mpdaf
#   Downloading mpdaf-3.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: numpy>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from mpdaf) (1.26.4)
# Requirement already satisfied: scipy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from mpdaf) (1.13.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mpdaf) (3.7.1)
# Requirement already satisfied: astropy>=1.0 in /usr/local/lib/python3.10/dist-packages (from mpdaf) (6.1.3)
# Collecting specutils (from mpdaf)
#   Downloading specutils-1.16.0-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.10/dist-packages (from astropy>=1.0->mpdaf) (2.0.1.4)
# Requirement already satisfied: astropy-iers-data>=0.2024.7.29.0.32.7 in /usr/local/lib/python3.10/dist-packages (from astropy>=1.0->mpdaf) (0.2024.8.27.10.28.29)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.10/dist-packages (from astropy>=1.0->mpdaf) (6.0.2)
# Requirement already satisfied: packaging>=19.0 in /usr/local/lib/python3.10/dist-packages (from astropy>=1.0->mpdaf) (24.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mpdaf) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mpdaf) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mpdaf) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mpdaf) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mpdaf) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mpdaf) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mpdaf) (2.8.2)
# Collecting gwcs>=0.18 (from specutils->mpdaf)
#   Downloading gwcs-0.21.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting asdf-astropy>=0.3 (from specutils->mpdaf)
#   Downloading asdf_astropy-0.6.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting asdf>=2.14.4 (from specutils->mpdaf)
#   Downloading asdf-3.4.0-py3-none-any.whl.metadata (14 kB)
# Collecting ndcube>=2.0 (from specutils->mpdaf)
#   Downloading ndcube-2.2.2-py3-none-any.whl.metadata (6.9 kB)
# Collecting asdf-standard>=1.1.0 (from asdf>=2.14.4->specutils->mpdaf)
#   Downloading asdf_standard-1.1.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting asdf-transform-schemas>=0.3 (from asdf>=2.14.4->specutils->mpdaf)
#   Downloading asdf_transform_schemas-0.5.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting jmespath>=0.6.2 (from asdf>=2.14.4->specutils->mpdaf)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting semantic-version>=2.8 (from asdf>=2.14.4->specutils->mpdaf)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from asdf>=2.14.4->specutils->mpdaf) (24.2.0)
# Requirement already satisfied: importlib-metadata>=4.11.4 in /usr/local/lib/python3.10/dist-packages (from asdf>=2.14.4->specutils->mpdaf) (8.4.0)
# Collecting asdf-coordinates-schemas>=0.3 (from asdf-astropy>=0.3->specutils->mpdaf)
#   Downloading asdf_coordinates_schemas-0.3.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting asdf-wcs-schemas>=0.4.0 (from gwcs>=0.18->specutils->mpdaf)
#   Downloading asdf_wcs_schemas-0.4.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mpdaf) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.11.4->asdf>=2.14.4->specutils->mpdaf) (3.20.1)
# Downloading mpdaf-3.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (59.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 MB 10.2 MB/s eta 0:00:00
# Downloading specutils-1.16.0-py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 86.1 MB/s eta 0:00:00
# Downloading asdf-3.4.0-py3-none-any.whl (968 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 968.0/968.0 kB 45.1 MB/s eta 0:00:00
# Downloading asdf_astropy-0.6.1-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 kB 5.8 MB/s eta 0:00:00
# Downloading gwcs-0.21.0-py3-none-any.whl (155 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 11.8 MB/s eta 0:00:00
# Downloading ndcube-2.2.2-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 8.9 MB/s eta 0:00:00
# Downloading asdf_coordinates_schemas-0.3.0-py3-none-any.whl (33 kB)
# Downloading asdf_standard-1.1.1-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 5.6 MB/s eta 0:00:00
# Downloading asdf_transform_schemas-0.5.0-py3-none-any.whl (275 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.4/275.4 kB 18.0 MB/s eta 0:00:00
# Downloading asdf_wcs_schemas-0.4.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 3.1 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Installing collected packages: semantic-version, jmespath, asdf-standard, asdf-transform-schemas, asdf, asdf-coordinates-schemas, asdf-wcs-schemas, asdf-astropy, gwcs, ndcube, specutils, mpdaf
# Successfully installed asdf-3.4.0 asdf-astropy-0.6.1 asdf-coordinates-schemas-0.3.0 asdf-standard-1.1.1 asdf-transform-schemas-0.5.0 asdf-wcs-schemas-0.4.0 gwcs-0.21.0 jmespath-1.0.1 mpdaf-3.6 ndcube-2.2.2 semantic-version-2.10.0 specutils-1.16.0

# %%
from astropy.coordinates import SkyCoord
from astropy import units as u
import mpdaf as mpdaf

# Aquí tienen una lista de 4 coordenadas extraídas de la Tabla 1 del artículo https://arxiv.org/pdf/2203.13759
# s0(a) =  9:21:25.040, 18:10:12.27    (RA, DEC)
# s0(b) =  9:21:25.858, 18:10:07.24    (RA, DEC)
# s0(c) =  9:21:26.439, 18:10:13.60    (RA, DEC)
# s0(d) =  9:21:25.781, 18:10:24.64    (RA, DEC)

# Cree un objeto SkyCoord para cada una de las coordenadas anteriores.
s0a = SkyCoord(ra='9:21:25.040',dec='18:10:12.27', unit=(u.hourangle, u.deg), frame='icrs')
s0b = SkyCoord(ra='9:21:25.858',dec='18:10:07.24', unit=(u.hourangle, u.deg), frame='icrs')
s0c = SkyCoord(ra='9:21:26.439',dec='18:10:13.60', unit=(u.hourangle, u.deg), frame='icrs')
s0d = SkyCoord(ra='9:21:25.781',dec='18:10:24.64', unit=(u.hourangle, u.deg), frame='icrs')

# Esto mostrará las coordenadas en grados de la primera coordenada.
print('s0a = (RA, DEC) = ',s0a.ra.value,',' ,s0a.dec.value)
# Out:
# s0a = (RA, DEC) =  140.3543333333333 , 18.170075

# %% [markdown]
# Cargaremos el cubo con mpdaf y luego extraeremos espectros con aperturas circulares.

# %%
# Cargamos con mpdaf
cube = mpdaf.obj.Cube(path_archivo)

# %% [markdown]
# Busque la documentación de mpdaf.obj.Cube, allí encontrará el método "aperture".
# Este método extrae un espectro de una apertura circular en el cubo.
#
# Averigue como utilizar dicha función para extraer un espectro en cada coordenada antes creada
# considerando, una apertura de diámetro de 2"
# Un pequeño hint: el centro debe ser de la forma (dec, ra) y cada coordenada con su valor en grados.

# %%
# Rellene el código a continuación reemplazando el "CENTRO" y "radio", según corresponda.
# Note que ya le hemos indicado al método las unidades de medida, por lo que debe ser consistente.

RADIO = 1

espectro_s0a = cube.aperture((s0a.dec.value, s0a.ra.value), RADIO, unit_center=u.deg, unit_radius=u.arcsec)
espectro_s0b = cube.aperture((s0b.dec.value, s0b.ra.value), RADIO, unit_center=u.deg, unit_radius=u.arcsec)
espectro_s0c = cube.aperture((s0c.dec.value, s0c.ra.value), RADIO, unit_center=u.deg, unit_radius=u.arcsec)
espectro_s0d = cube.aperture((s0d.dec.value, s0d.ra.value), RADIO, unit_center=u.deg, unit_radius=u.arcsec)
# Out:
# [INFO] 100 spaxels used
# INFO:mpdaf.obj.data:100 spaxels used
# [INFO] 100 spaxels used
# INFO:mpdaf.obj.data:100 spaxels used
# [INFO] 100 spaxels used
# INFO:mpdaf.obj.data:100 spaxels used
# [INFO] 100 spaxels used
# INFO:mpdaf.obj.data:100 spaxels used

# %% [markdown]
# Grafique los 4 espectros en un único gráfico. Notará que es bastante difícil descifrar algo de forma directa con plots "crudos". Estos espectros se ven todos bastante parecidos.
#
# Grafique únicamente el rango de longitud de onda entre 9240-9310 Å.
# Para esto puede utilizar el método "plot" de los objetos antes creados.

# %%
# Inserte su gráfico a continuación:

wavelength_range = [9240, 9310]

plt.figure(figsize=(10, 6))

i = 0
letra = ['a', 'b', 'c', 'd']

for espectro in [espectro_s0a, espectro_s0b, espectro_s0c, espectro_s0d]:
  plt.plot(espectro.wave.coord(), espectro.data, label=f'Espectro {letra[i]}')
  i += 1

# Limitar el rango de longitud de onda
plt.xlim(wavelength_range)

# Personalizar el gráfico
plt.xlabel('Longitud de onda')
plt.ylabel('Flujo')
plt.title('Espectros en el rango 9240-9310 Å')
plt.legend()
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Notará que hay una emisión bastante clara con 2 máximos, uno detrás de otro.
# Esto es lo que se conoce como líneas espectrales de emisión de una galaxia.
# En particular, estas líneas parecen ser todas iguales entre los distintos espectros. Los autores del artículo antes mencionado afirman que estas 4 coordenadas provienen de una misma única fuente de fondo, ¿cómo justificarían dicha afirmación con el gráfico que obtuvieron recién?
#
# **Respuesta: (algo corto y simple!)** Es la misma galaxia debido a que proviene de coordenadas similares y emite las mismas longitudes de onda que entre otras caracteristicas nos permite conocer su composición, además lo único que cambia es la intensidad del flujo.

# %% [markdown]
# Esta emisión proviene del gas de estas fuentes, en particular es una línea de  OII, es decir, oxígeno que fue ionizado. Esta línea es lo que se conoce como un "doblete" (doublet en inglés), lo que quiere decir que en realidad son dos líneas, muy cercanas en longitud de onda. La longitud de onda medida en laboratorio de ambas líneas es 3727.092 Å y 3729.875 Å, respectivamente. Claramente las líneas que vemos en estas fuentes no están centradas en esas longitudes de onda.
#
# El desplazamiento aparente de las longitudes de onda, con respecto a aquellas medidas en el laboratorio, es un efecto de la expansión del universo. La expansión genera que los fotones pasen a tener una longitud de onda cada vez más larga a medida que se alejan de un observador. Esto se suele definir con la cantidad "redshift" (z) definida por:
#
# $$\lambda_{obs} = (1+z) \lambda_0 $$
#
# donde $\lambda_{obs}$ y $\lambda_0$ corresponde a la longitud de onda observada y aquella medida en el laboratorio. Vamos a determinar el redshift de esta fuente, para ello fitearemos un modelo que considera dos gaussianas (una para cada línea) y una constante, es decir nuestro modelo es de la forma:
#
# $$f(\lambda, z,  A_1, \sigma_1, A_2, \sigma_2, C) = A_1 \exp(-(\lambda - (1+z)\lambda_{0,1})^2 /(2 \sigma_1^2 ))  + A_2 \exp(-(\lambda - (1+z)\lambda_{0,2})^2 /(2 \sigma_2^2 )) + C$$
#
# Donde $\lambda_{0,1} = 3727.092$ Å y $\lambda_{0,2} = 3729.875$ Å.
#
# MPDAF ya es capaz de hacer este fit por nosotros, para ello proceda como se le indica:
#
# 1. Note que cada espectro antes producido es un objeto de Python, dichos objetos tienen como método gauss_dfit. Explore la documentación de mpdaf y busque el método gauss_dfit. Describa los 3 primeros parámetros de dicha función.
# **Respuesta:** Parámetros:
#
# lmin (float):
# Valor de longitud de onda mínimo o rango de longitud de onda utilizado para inicializar el valor izquierdo gaussiano.
#
# lmax (float):
# Longitud de onda máxima o rango de longitud de onda utilizado para inicializar el valor correcto gaussiano.
#
# wratio (float):
# Relación entre los dos centros gaussianos.
#
# 2. Considerando que vamos a hacer nuestro fit en el rango 9240-9310 Å, utilice el método antes descrito.
#
# 3. El resultado deberían ser dos objetos de tipo obj.Gauss1D, utilice el método print_param() para mostrar los resultados de cada fit.

# %%
# Utilice el método gauss_dfit (solo utilizaremos un espectro de los antes calculados, no necesitamos los 4)
fit1, fit2 = espectro_s0a.gauss_dfit(9240,9310, 3729.875 / 3727.092)  # rellene con los parámetros adecuados

# Haga el print de los parámetros del primer objeto Gauss1D (fit1) (utilice el método "print_param" para esto)
fit1.print_param()
# Out:
# [INFO] Gaussian center = 9273.61 (error:0.584382)
# INFO:mpdaf.obj.fitting:Gaussian center = 9273.61 (error:0.584382)
# [INFO] Gaussian integrated flux = 16105.4 (error:1984.9)
# INFO:mpdaf.obj.fitting:Gaussian integrated flux = 16105.4 (error:1984.9)
# [INFO] Gaussian peak value = 1215.54 (error:41.4936)
# INFO:mpdaf.obj.fitting:Gaussian peak value = 1215.54 (error:41.4936)
# [INFO] Gaussian fwhm = 12.4471 (error:1.10914)
# INFO:mpdaf.obj.fitting:Gaussian fwhm = 12.4471 (error:1.10914)
# [INFO] Gaussian continuum = 208.692
# INFO:mpdaf.obj.fitting:Gaussian continuum = 208.692

# %%
# Haga el print de los parámetros del segundo objeto Gauss1D (fit2)
fit2.print_param()
# Out:
# [INFO] Gaussian center = 9280.54 (error:0.584818)
# INFO:mpdaf.obj.fitting:Gaussian center = 9280.54 (error:0.584818)
# [INFO] Gaussian integrated flux = -4040.35 (error:2124.7)
# INFO:mpdaf.obj.fitting:Gaussian integrated flux = -4040.35 (error:2124.7)
# [INFO] Gaussian peak value = -304.942 (error:187.533)
# INFO:mpdaf.obj.fitting:Gaussian peak value = -304.942 (error:187.533)
# [INFO] Gaussian fwhm = 12.4471 (error:1.10914)
# INFO:mpdaf.obj.fitting:Gaussian fwhm = 12.4471 (error:1.10914)
# [INFO] Gaussian continuum = 208.692
# INFO:mpdaf.obj.fitting:Gaussian continuum = 208.692

# %% [markdown]
# Note que los modelos no reportan las variables $\sigma$ antes descritas, sino que para describir el ancho utilizan la variable fwhm lo cual es una abreviación para la palabra Full width at half Maximum (ancho a media altura en español).
#
# Responda:
# - ¿Qué es el FWHM?
# - Para una distribución normal, escriba una ecuación que relacione el FWHM con la desviación estándar $\sigma$ (no es necesario que la demuestre).
#
# **Respuesta:**
#
# 1. El FWHM (Full Width at Half Maximum) es una medida del ancho de una distribución en su punto medio. Específicamente, en una curva gaussiana, el FWHM es la distancia entre los dos puntos de la curva donde el valor de la función es la mitad de su valor máximo.
#
# 2. $FWHM = 2.355*\sigma$

# %% [markdown]
# Ahora, veremos que tan bien lo hizo este modelo, para ello graficaremos encima del espectro el modelo que se obtuvo.

# %%
# Función de ayuda para la siguiente parte :)

def gaussian(x, center, fwhm, peak):
  sigma = fwhm/2.355
  dif = x - center
  return peak * np.exp(-(dif**2)/(2*sigma**2))

# %% [markdown]
# Realice un gráfico que contenga el espectro en el cual se realizó el "fit" y el modelo encontrado.
# Para ello debe implementar la función $f(\lambda, z,  A_1, \sigma_1, A_2, \sigma_2, C)$. Esto se puede realizar utilizando la función "gaussian" del bloque anterior o puede hacer su propia implementación desde 0.
#
# Solo grafique el rango entre 9240-9310 angstroms. Recuerde incluír alguna leyenda, nombres en los ejes, título, etc.

# %%
def f_modelo(plambda, pz, pA1, psigma1, pA2, psigma2, C):
  lambda1 = 3727.092  # Longitud de onda de la primera línea de OII
  lambda2 = 3729.875  # Longitud de onda de la segunda línea de OII
  print(f"f_modelo llamado: {gaussian(plambda, (1+pz) * lambda1, psigma1, pA1) + gaussian(plambda, (1+pz) * lambda2, psigma2, pA2)}")
  return gaussian(plambda, (1+pz) * lambda1, psigma1, pA1) + gaussian(plambda, (1+pz) * lambda2, psigma2, pA2)

# parametros obtenidos del fit
z = 9273.61/3727.092 - 1
A1 = 1215.54
sigma1 = 12.4471
A2 = -304.942
sigma2 = 12.4471
C = 208.692

lambda0 = np.linspace(9240, 9310, 1000)

# Inserte aquí su gráfico:
plt.figure(figsize=(10, 6))

i = 0

#for espectro in [espectro_s0a, espectro_s0b, espectro_s0c, espectro_s0d]:
#  plt.plot(, , label=f'Espectro {letra[i]}')
#  i += 1

plt.xlim(wavelength_range)

plt.plot(lambda0, f_modelo(lambda0, z, A1, sigma1, A2, sigma2, C), label="Modelo ajustado", color="red")
plt.plot(espectro_s0a.wave.coord(), espectro_s0a.data, label="Espectro", color="blue", alpha=0.6)  # Simulación de espectro

plt.xlabel("Longitud de onda")
plt.ylabel("Intensidad")
plt.title("Ajuste de modelo sobre el espectro en el rango 9240-9310 Å")
plt.legend()
plt.show()
# Out:
# f_modelo llamado: [ 2.01327508e-06  2.19016776e-06  2.38218404e-06  2.59057940e-06
#   2.81671022e-06  3.06204169e-06  3.32815615e-06  3.61676221e-06
#   3.92970441e-06  4.26897369e-06  4.63671860e-06  5.03525728e-06
#   5.46709044e-06  5.93491518e-06  6.44163987e-06  6.99040006e-06
#   7.58457565e-06  8.22780914e-06  8.92402536e-06  9.67745250e-06
#   1.04926447e-05  1.13745061e-05  1.23283171e-05  1.33597617e-05
#   1.44749573e-05  1.56804865e-05  1.69834314e-05  1.83914096e-05
#   1.99126130e-05  2.15558502e-05  2.33305901e-05  2.52470102e-05
#   2.73160470e-05  2.95494507e-05  3.19598429e-05  3.45607791e-05
#   3.73668145e-05  4.03935750e-05  4.36578326e-05  4.71775860e-05
#   5.09721464e-05  5.50622294e-05  5.94700529e-05  6.42194410e-05
#   6.93359356e-05  7.48469147e-05  8.07817184e-05  8.71717842e-05
#   9.40507894e-05  1.01454804e-04  1.09422454e-04  1.17995093e-04
#   1.27216987e-04  1.37135510e-04  1.47801353e-04  1.59268743e-04
#   1.71595683e-04  1.84844198e-04  1.99080604e-04  2.14375790e-04
#   2.30805518e-04  2.48450741e-04  2.67397945e-04  2.87739507e-04
#   3.09574076e-04  3.33006978e-04  3.58150650e-04  3.85125090e-04
#   4.14058344e-04  4.45087019e-04  4.78356824e-04  5.14023151e-04
#   5.52251676e-04  5.93219016e-04  6.37113407e-04  6.84135430e-04
#   7.34498779e-04  7.88431071e-04  8.46174710e-04  9.07987791e-04
#   9.74145062e-04  1.04493894e-03  1.12068059e-03  1.20170106e-03
#   1.28835247e-03  1.38100929e-03  1.48006967e-03  1.58595688e-03
#   1.69912075e-03  1.82003931e-03  1.94922040e-03  2.08720344e-03
#   2.23456128e-03  2.39190215e-03  2.55987172e-03  2.73915526e-03
#   2.93047991e-03  3.13461711e-03  3.35238511e-03  3.58465164e-03
#   3.83233675e-03  4.09641569e-03  4.37792209e-03  4.67795120e-03
#   4.99766332e-03  5.33828742e-03  5.70112496e-03  6.08755385e-03
#   6.49903268e-03  6.93710509e-03  7.40340442e-03  7.89965858e-03
#   8.42769513e-03  8.98944662e-03  9.58695625e-03  1.02223837e-02
#   1.08980114e-02  1.16162508e-02  1.23796495e-02  1.31908980e-02
#   1.40528372e-02  1.49684667e-02  1.59409521e-02  1.69736342e-02
#   1.80700379e-02  1.92338813e-02  2.04690854e-02  2.17797848e-02
#   2.31703381e-02  2.46453390e-02  2.62096282e-02  2.78683054e-02
#   2.96267424e-02  3.14905958e-02  3.34658214e-02  3.55586887e-02
#   3.77757956e-02  4.01240846e-02  4.26108590e-02  4.52437999e-02
#   4.80309847e-02  5.09809048e-02  5.41024857e-02  5.74051068e-02
#   6.08986226e-02  6.45933842e-02  6.85002627e-02  7.26306720e-02
#   7.69965940e-02  8.16106042e-02  8.64858975e-02  9.16363169e-02
#   9.70763810e-02  1.02821315e-01  1.08887080e-01  1.15290406e-01
#   1.22048827e-01  1.29180710e-01  1.36705298e-01  1.44642740e-01
#   1.53014135e-01  1.61841569e-01  1.71148156e-01  1.80958081e-01
#   1.91296644e-01  2.02190308e-01  2.13666742e-01  2.25754872e-01
#   2.38484932e-01  2.51888514e-01  2.65998625e-01  2.80849739e-01
#   2.96477857e-01  3.12920563e-01  3.30217091e-01  3.48408379e-01
#   3.67537143e-01  3.87647938e-01  4.08787228e-01  4.31003458e-01
#   4.54347127e-01  4.78870860e-01  5.04629490e-01  5.31680135e-01
#   5.60082278e-01  5.89897854e-01  6.21191332e-01  6.54029810e-01
#   6.88483099e-01  7.24623819e-01  7.62527495e-01  8.02272655e-01
#   8.43940927e-01  8.87617146e-01  9.33389457e-01  9.81349425e-01
#   1.03159214e+00  1.08421633e+00  1.13932449e+00  1.19702297e+00
#   1.25742213e+00  1.32063645e+00  1.38678462e+00  1.45598973e+00
#   1.52837936e+00  1.60408570e+00  1.68324574e+00  1.76600135e+00
#   1.85249944e+00  1.94289211e+00  2.03733679e+00  2.13599638e+00
#   2.23903939e+00  2.34664013e+00  2.45897881e+00  2.57624173e+00
#   2.69862143e+00  2.82631684e+00  2.95953343e+00  3.09848343e+00
#   3.24338589e+00  3.39446696e+00  3.55195996e+00  3.71610562e+00
#   3.88715219e+00  4.06535565e+00  4.25097987e+00  4.44429676e+00
#   4.64558649e+00  4.85513760e+00  5.07324722e+00  5.30022122e+00
#   5.53637440e+00  5.78203061e+00  6.03752302e+00  6.30319418e+00
#   6.57939626e+00  6.86649121e+00  7.16485088e+00  7.47485727e+00
#   7.79690259e+00  8.13138951e+00  8.47873126e+00  8.83935183e+00
#   9.21368608e+00  9.60217991e+00  1.00052904e+01  1.04234860e+01
#   1.08572466e+01  1.13070635e+01  1.17734402e+01  1.22568915e+01
#   1.27579444e+01  1.32771381e+01  1.38150238e+01  1.43721650e+01
#   1.49491376e+01  1.55465299e+01  1.61649427e+01  1.68049895e+01
#   1.74672964e+01  1.81525021e+01  1.88612580e+01  1.95942285e+01
#   2.03520905e+01  2.11355338e+01  2.19452610e+01  2.27819875e+01
#   2.36464411e+01  2.45393628e+01  2.54615059e+01  2.64136362e+01
#   2.73965322e+01  2.84109847e+01  2.94577968e+01  3.05377837e+01
#   3.16517725e+01  3.28006023e+01  3.39851239e+01  3.52061993e+01
#   3.64647021e+01  3.77615166e+01  3.90975382e+01  4.04736725e+01
#   4.18908356e+01  4.33499534e+01  4.48519613e+01  4.63978041e+01
#   4.79884355e+01  4.96248174e+01  5.13079203e+01  5.30387218e+01
#   5.48182071e+01  5.66473679e+01  5.85272024e+01  6.04587141e+01
#   6.24429120e+01  6.44808096e+01  6.65734243e+01  6.87217771e+01
#   7.09268915e+01  7.31897934e+01  7.55115099e+01  7.78930688e+01
#   8.03354980e+01  8.28398246e+01  8.54070739e+01  8.80382692e+01
#   9.07344304e+01  9.34965733e+01  9.63257090e+01  9.92228425e+01
#   1.02188972e+02  1.05225089e+02  1.08332175e+02  1.11511203e+02
#   1.14763135e+02  1.18088920e+02  1.21489496e+02  1.24965788e+02
#   1.28518703e+02  1.32149136e+02  1.35857960e+02  1.39646035e+02
#   1.43514199e+02  1.47463268e+02  1.51494039e+02  1.55607285e+02
#   1.59803755e+02  1.64084171e+02  1.68449230e+02  1.72899601e+02
#   1.77435924e+02  1.82058808e+02  1.86768829e+02  1.91566533e+02
#   1.96452430e+02  2.01426993e+02  2.06490661e+02  2.11643832e+02
#   2.16886867e+02  2.22220085e+02  2.27643763e+02  2.33158135e+02
#   2.38763389e+02  2.44459669e+02  2.50247070e+02  2.56125641e+02
#   2.62095379e+02  2.68156232e+02  2.74308093e+02  2.80550805e+02
#   2.86884155e+02  2.93307873e+02  2.99821636e+02  3.06425060e+02
#   3.13117702e+02  3.19899060e+02  3.26768572e+02  3.33725612e+02
#   3.40769492e+02  3.47899460e+02  3.55114700e+02  3.62414328e+02
#   3.69797396e+02  3.77262888e+02  3.84809720e+02  3.92436739e+02
#   4.00142724e+02  4.07926382e+02  4.15786352e+02  4.23721201e+02
#   4.31729425e+02  4.39809447e+02  4.47959622e+02  4.56178227e+02
#   4.64463473e+02  4.72813493e+02  4.81226350e+02  4.89700035e+02
#   4.98232465e+02  5.06821486e+02  5.15464871e+02  5.24160320e+02
#   5.32905463e+02  5.41697858e+02  5.50534993e+02  5.59414286e+02
#   5.68333083e+02  5.77288665e+02  5.86278240e+02  5.95298954e+02
#   6.04347884e+02  6.13422040e+02  6.22518371e+02  6.31633760e+02
#   6.40765031e+02  6.49908945e+02  6.59062203e+02  6.68221452e+02
#   6.77383279e+02  6.86544218e+02  6.95700749e+02  7.04849302e+02
#   7.13986256e+02  7.23107943e+02  7.32210650e+02  7.41290620e+02
#   7.50344054e+02  7.59367113e+02  7.68355924e+02  7.77306575e+02
#   7.86215124e+02  7.95077600e+02  8.03890001e+02  8.12648302e+02
#   8.21348456e+02  8.29986396e+02  8.38558037e+02  8.47059280e+02
#   8.55486015e+02  8.63834123e+02  8.72099479e+02  8.80277955e+02
#   8.88365425e+02  8.96357762e+02  9.04250850e+02  9.12040578e+02
#   9.19722850e+02  9.27293585e+02  9.34748719e+02  9.42084211e+02
#   9.49296044e+02  9.56380231e+02  9.63332814e+02  9.70149871e+02
#   9.76827515e+02  9.83361904e+02  9.89749235e+02  9.95985757e+02
#   1.00206777e+03  1.00799161e+03  1.01375370e+03  1.01935050e+03
#   1.02477855e+03  1.03003443e+03  1.03511481e+03  1.04001642e+03
#   1.04473609e+03  1.04927069e+03  1.05361719e+03  1.05777265e+03
#   1.06173421e+03  1.06549909e+03  1.06906461e+03  1.07242818e+03
#   1.07558732e+03  1.07853962e+03  1.08128281e+03  1.08381469e+03
#   1.08613317e+03  1.08823630e+03  1.09012219e+03  1.09178911e+03
#   1.09323541e+03  1.09445957e+03  1.09546018e+03  1.09623596e+03
#   1.09678574e+03  1.09710847e+03  1.09720324e+03  1.09706925e+03
#   1.09670582e+03  1.09611241e+03  1.09528860e+03  1.09423410e+03
#   1.09294874e+03  1.09143249e+03  1.08968545e+03  1.08770784e+03
#   1.08550002e+03  1.08306247e+03  1.08039581e+03  1.07750078e+03
#   1.07437826e+03  1.07102926e+03  1.06745490e+03  1.06365644e+03
#   1.05963528e+03  1.05539292e+03  1.05093101e+03  1.04625132e+03
#   1.04135572e+03  1.03624624e+03  1.03092500e+03  1.02539424e+03
#   1.01965635e+03  1.01371379e+03  1.00756918e+03  1.00122521e+03
#   9.94684704e+02  9.87950594e+02  9.81025910e+02  9.73913788e+02
#   9.66617466e+02  9.59140279e+02  9.51485660e+02  9.43657135e+02
#   9.35658318e+02  9.27492914e+02  9.19164712e+02  9.10677584e+02
#   9.02035478e+02  8.93242422e+02  8.84302514e+02  8.75219923e+02
#   8.65998884e+02  8.56643695e+02  8.47158716e+02  8.37548360e+02
#   8.27817095e+02  8.17969440e+02  8.08009956e+02  7.97943252e+02
#   7.87773972e+02  7.77506797e+02  7.67146441e+02  7.56697644e+02
#   7.46165173e+02  7.35553817e+02  7.24868379e+02  7.14113681e+02
#   7.03294550e+02  6.92415825e+02  6.81482346e+02  6.70498953e+02
#   6.59470482e+02  6.48401763e+02  6.37297615e+02  6.26162841e+02
#   6.15002229e+02  6.03820546e+02  5.92622533e+02  5.81412905e+02
#   5.70196347e+02  5.58977507e+02  5.47761001e+02  5.36551399e+02
#   5.25353234e+02  5.14170988e+02  5.03009096e+02  4.91871943e+02
#   4.80763857e+02  4.69689109e+02  4.58651911e+02  4.47656413e+02
#   4.36706701e+02  4.25806790e+02  4.14960630e+02  4.04172098e+02
#   3.93444995e+02  3.82783049e+02  3.72189908e+02  3.61669143e+02
#   3.51224242e+02  3.40858608e+02  3.30575563e+02  3.20378340e+02
#   3.10270085e+02  3.00253855e+02  2.90332618e+02  2.80509250e+02
#   2.70786533e+02  2.61167157e+02  2.51653718e+02  2.42248717e+02
#   2.32954559e+02  2.23773552e+02  2.14707910e+02  2.05759746e+02
#   1.96931079e+02  1.88223829e+02  1.79639817e+02  1.71180769e+02
#   1.62848311e+02  1.54643972e+02  1.46569184e+02  1.38625282e+02
#   1.30813504e+02  1.23134991e+02  1.15590789e+02  1.08181850e+02
#   1.00909030e+02  9.37730920e+01  8.67747062e+01  7.99144509e+01
#   7.31928138e+01  6.66101924e+01  6.01668957e+01  5.38631450e+01
#   4.76990753e+01  4.16747368e+01  3.57900955e+01  3.00450356e+01
#   2.44393602e+01  1.89727930e+01  1.36449801e+01  8.45549097e+00
#   3.40382086e+00 -1.51060812e+00 -6.28844508e+00 -1.09304086e+01
#  -1.54372851e+01 -1.98099269e+01 -2.40492503e+01 -2.81562341e+01
#  -3.21319174e+01 -3.59773977e+01 -3.96938292e+01 -4.32824208e+01
#  -4.67444340e+01 -5.00811811e+01 -5.32940234e+01 -5.63843688e+01
#  -5.93536702e+01 -6.22034233e+01 -6.49351649e+01 -6.75504705e+01
#  -7.00509527e+01 -7.24382593e+01 -7.47140708e+01 -7.68800990e+01
#  -7.89380850e+01 -8.08897968e+01 -8.27370282e+01 -8.44815960e+01
#  -8.61253388e+01 -8.76701150e+01 -8.91178006e+01 -9.04702880e+01
#  -9.17294837e+01 -9.28973067e+01 -9.39756870e+01 -9.49665633e+01
#  -9.58718822e+01 -9.66935956e+01 -9.74336599e+01 -9.80940338e+01
#  -9.86766771e+01 -9.91835492e+01 -9.96166072e+01 -9.99778052e+01
#  -1.00269092e+02 -1.00492410e+02 -1.00649696e+02 -1.00742874e+02
#  -1.00773862e+02 -1.00744565e+02 -1.00656874e+02 -1.00512668e+02
#  -1.00313812e+02 -1.00062154e+02 -9.97595241e+01 -9.94077368e+01
#  -9.90085865e+01 -9.85638483e+01 -9.80752766e+01 -9.75446047e+01
#  -9.69735436e+01 -9.63637815e+01 -9.57169830e+01 -9.50347886e+01
#  -9.43188138e+01 -9.35706488e+01 -9.27918579e+01 -9.19839787e+01
#  -9.11485220e+01 -9.02869713e+01 -8.94007822e+01 -8.84913824e+01
#  -8.75601709e+01 -8.66085181e+01 -8.56377655e+01 -8.46492252e+01
#  -8.36441801e+01 -8.26238835e+01 -8.15895590e+01 -8.05424005e+01
#  -7.94835721e+01 -7.84142079e+01 -7.73354123e+01 -7.62482599e+01
#  -7.51537953e+01 -7.40530336e+01 -7.29469603e+01 -7.18365313e+01
#  -7.07226733e+01 -6.96062836e+01 -6.84882309e+01 -6.73693548e+01
#  -6.62504667e+01 -6.51323495e+01 -6.40157583e+01 -6.29014203e+01
#  -6.17900356e+01 -6.06822769e+01 -5.95787904e+01 -5.84801960e+01
#  -5.73870874e+01 -5.63000327e+01 -5.52195749e+01 -5.41462321e+01
#  -5.30804980e+01 -5.20228423e+01 -5.09737111e+01 -4.99335274e+01
#  -4.89026916e+01 -4.78815818e+01 -4.68705543e+01 -4.58699442e+01
#  -4.48800659e+01 -4.39012130e+01 -4.29336598e+01 -4.19776608e+01
#  -4.10334517e+01 -4.01012497e+01 -3.91812544e+01 -3.82736474e+01
#  -3.73785938e+01 -3.64962419e+01 -3.56267241e+01 -3.47701574e+01
#  -3.39266436e+01 -3.30962698e+01 -3.22791094e+01 -3.14752218e+01
#  -3.06846533e+01 -2.99074378e+01 -2.91435965e+01 -2.83931393e+01
#  -2.76560642e+01 -2.69323589e+01 -2.62220002e+01 -2.55249551e+01
#  -2.48411808e+01 -2.41706255e+01 -2.35132285e+01 -2.28689208e+01
#  -2.22376254e+01 -2.16192577e+01 -2.10137259e+01 -2.04209313e+01
#  -1.98407690e+01 -1.92731276e+01 -1.87178902e+01 -1.81749345e+01
#  -1.76441329e+01 -1.71253534e+01 -1.66184593e+01 -1.61233097e+01
#  -1.56397603e+01 -1.51676628e+01 -1.47068660e+01 -1.42572154e+01
#  -1.38185543e+01 -1.33907230e+01 -1.29735600e+01 -1.25669018e+01
#  -1.21705831e+01 -1.17844371e+01 -1.14082959e+01 -1.10419905e+01
#  -1.06853509e+01 -1.03382067e+01 -1.00003869e+01 -9.67172023e+00
#  -9.35203543e+00 -9.04116119e+00 -8.73892646e+00 -8.44516060e+00
#  -8.15969345e+00 -7.88235553e+00 -7.61297817e+00 -7.35139360e+00
#  -7.09743508e+00 -6.85093704e+00 -6.61173515e+00 -6.37966645e+00
#  -6.15456940e+00 -5.93628404e+00 -5.72465200e+00 -5.51951662e+00
#  -5.32072301e+00 -5.12811811e+00 -4.94155076e+00 -4.76087178e+00
#  -4.58593396e+00 -4.41659219e+00 -4.25270342e+00 -4.09412678e+00
#  -3.94072354e+00 -3.79235719e+00 -3.64889347e+00 -3.51020035e+00
#  -3.37614811e+00 -3.24660929e+00 -3.12145876e+00 -3.00057371e+00
#  -2.88383365e+00 -2.77112043e+00 -2.66231821e+00 -2.55731352e+00
#  -2.45599518e+00 -2.35825437e+00 -2.26398456e+00 -2.17308152e+00
#  -2.08544335e+00 -2.00097041e+00 -1.91956530e+00 -1.84113291e+00
#  -1.76558034e+00 -1.69281688e+00 -1.62275404e+00 -1.55530547e+00
#  -1.49038696e+00 -1.42791642e+00 -1.36781385e+00 -1.31000130e+00
#  -1.25440285e+00 -1.20094459e+00 -1.14955458e+00 -1.10016282e+00
#  -1.05270122e+00 -1.00710356e+00 -9.63305479e-01 -9.21244434e-01
#  -8.80859653e-01 -8.42092115e-01 -8.04884516e-01 -7.69181234e-01
#  -7.34928295e-01 -7.02073338e-01 -6.70565587e-01 -6.40355811e-01
#  -6.11396293e-01 -5.83640797e-01 -5.57044535e-01 -5.31564133e-01
#  -5.07157595e-01 -4.83784279e-01 -4.61404853e-01 -4.39981273e-01
#  -4.19476745e-01 -3.99855694e-01 -3.81083736e-01 -3.63127643e-01
#  -3.45955316e-01 -3.29535754e-01 -3.13839022e-01 -2.98836225e-01
#  -2.84499476e-01 -2.70801871e-01 -2.57717459e-01 -2.45221217e-01
#  -2.33289018e-01 -2.21897610e-01 -2.11024589e-01 -2.00648369e-01
#  -1.90748163e-01 -1.81303958e-01 -1.72296485e-01 -1.63707203e-01
#  -1.55518274e-01 -1.47712535e-01 -1.40273487e-01 -1.33185262e-01
#  -1.26432611e-01 -1.20000879e-01 -1.13875987e-01 -1.08044412e-01
#  -1.02493168e-01 -9.72097879e-02 -9.21823055e-02 -8.73992386e-02
#  -8.28495715e-02 -7.85227384e-02 -7.44086080e-02 -7.04974674e-02
#  -6.67800073e-02 -6.32473069e-02 -5.98908203e-02 -5.67023621e-02
#  -5.36740941e-02 -5.07985126e-02 -4.80684354e-02 -4.54769898e-02
#  -4.30176007e-02 -4.06839793e-02 -3.84701117e-02 -3.63702485e-02
#  -3.43788940e-02 -3.24907968e-02 -3.07009395e-02 -2.90045296e-02
#  -2.73969904e-02 -2.58739523e-02 -2.44312444e-02 -2.30648862e-02
#  -2.17710797e-02 -2.05462023e-02 -1.93867987e-02 -1.82895747e-02
#  -1.72513897e-02 -1.62692509e-02 -1.53403061e-02 -1.44618384e-02
#  -1.36312602e-02 -1.28461073e-02 -1.21040338e-02 -1.14028068e-02
#  -1.07403014e-02 -1.01144961e-02 -9.52346788e-03 -8.96538798e-03
#  -8.43851766e-03 -7.94120405e-03 -7.47187632e-03 -7.02904186e-03
#  -6.61128274e-03 -6.21725222e-03 -5.84567149e-03 -5.49532645e-03
#  -5.16506474e-03 -4.85379279e-03 -4.56047303e-03 -4.28412129e-03
#  -4.02380419e-03 -3.77863672e-03 -3.54777993e-03 -3.33043868e-03
#  -3.12585952e-03 -2.93332865e-03 -2.75216996e-03 -2.58174320e-03
#  -2.42144221e-03 -2.27069318e-03 -2.12895308e-03 -1.99570809e-03
#  -1.87047215e-03 -1.75278554e-03 -1.64221354e-03 -1.53834519e-03
#  -1.44079201e-03 -1.34918690e-03 -1.26318301e-03 -1.18245271e-03
#  -1.10668655e-03 -1.03559236e-03 -9.68894310e-04 -9.06332048e-04
#  -8.47659900e-04 -7.92646079e-04 -7.41071946e-04 -6.92731308e-04
#  -6.47429747e-04 -6.04983986e-04 -5.65221284e-04 -5.27978869e-04
#  -4.93103385e-04 -4.60450385e-04 -4.29883836e-04 -4.01275656e-04
#  -3.74505274e-04 -3.49459212e-04 -3.26030691e-04 -3.04119252e-04
#  -2.83630406e-04 -2.64475293e-04 -2.46570365e-04 -2.29837085e-04
#  -2.14201639e-04 -1.99594668e-04 -1.85951013e-04 -1.73209469e-04
#  -1.61312561e-04 -1.50206323e-04 -1.39840100e-04 -1.30166348e-04
#  -1.21140454e-04 -1.12720568e-04 -1.04867431e-04 -9.75442297e-05
#  -9.07164482e-05 -8.43517299e-05 -7.84197501e-05 -7.28920931e-05
#  -6.77421379e-05 -6.29449494e-05 -5.84771764e-05 -5.43169553e-05]

# %% [markdown]
# Finalmente, con el resultado del fit, podemos encontrar el redshift de la fuente. Para ello simplemente calcule el redshift (z) utilizando la definición provista, considerando que la longitud de onda observada corresponde con algún centro de las gaussianas.

# %%
# Escriba aquí código para el cálculo:

lambda_0 =  3727.092  # consideramos la línea de longitud de onda más corta
lambda_observada = 9273.61
z = (lambda_observada / lambda_0) - 1
print('El redshift es: {:.3f}'.format(z))
# Out:
# El redshift es: 1.488

# %% [markdown]
# A modo de curiosidad, el redshift de esta galaxia indica que la luz que observamos se emitió hace poco menos de 10.000 millones de años, 2/3 de la edad del universo :o !!

# %% [markdown]
# ## Opcional: no todo es Python!
#
# Existe software capaz de proveer de una visualización y análisis rápido de datos como los que utilizamos en esta actividad. Uno de ellos especialmente diseñado para lidiar con cubos de datos es QfitsView.
# El software se puede descargar en el siguiente [link](https://www.mpe.mpg.de/~ott/QFitsView/).
#
# Descargue el software y abra directamente los datos descargados en su computador, para ello debe seleccionar la extensión "DATA". Notará que abrirá el cubo y podrá desplazarse a lo largo de todos los canales. Ajuste la escala a "linear" y utilizando el 98% del rango de los datos para un mejor contraste.
#
# Una pequeña guía para repetir todo lo que hicieron en la actividad:
# - A medida que mueve su "ratón" por sobre la imagen del canal seleccionado, verá que el "gráfico" de abajo cambia. Dicho gráfico por defecto es el espectro asociado al pixel en el cual su "ratón" está.
# - Podemos fijar el espectro que queremos visualizar, para ello haga click derecho en alguna fuente que quiera observar con detalle y seleccione "lock position".
# - Para mejorar la señal a ruido de los espectros es recomendable sumar la contribución de varios pixeles al mismo tiempo, para ello, en el gráfico del espectro en su parte superior, seleccione "Circular" en vez de "Single pixel" y aumente el radio (donde dice "R1") a unos 5 pixeles.
# - Si desea analizar en detalle dicho espectro, lo pueden guardar como un archivo fits, para ello solo deben apretar "click derecho" encima de la fuente de interés (sugiero una galaxia muy brillante en el sur-este cerca del arco gravitacional). También pueden guardarlo en otro "buffer" y solo cambiarse de buffer para ver cada espectro.
#
# Pueden aquí ver una serie de [videos tutorial](https://www.youtube.com/playlist?list=PLdVESrjTNUXtwxwysIDLoC4pV20Lbvqaz) si desean aprender más.
